# %% [markdown]
# # 9.4 Computer Use 概览
#
# 本笔记本介绍 Computer Use 的概念和 API 结构。
#
# **注意**: Computer Use 需要特殊环境，这里展示概念性代码。
#
# **预估成本**: ~$0.10

# %% [markdown]
# ## Anthropic Computer Use API 结构

# %%
# 概念代码 - 不实际运行
import anthropic

client = anthropic.Anthropic()

# Computer Use 工具定义
tools = [
    {
        'type': 'computer_20241022',
        'name': 'computer',
        'display_width_px': 1920,
        'display_height_px': 1080,
    }
]

print('Computer Use 工具结构展示')

# %% [markdown]
# ## 支持的操作类型

# %%
operations = {
    'key': '按键',
    'type': '输入文本',
    'mouse_move': '移动鼠标',
    'left_click': '左键点击',
    'screenshot': '截屏',
}

for op, desc in operations.items():
    print(f'{op}: {desc}')

# %% [markdown]
# ## 应用场景

# %%
scenarios = [
    '网页操作和数据采集',
    'UI 自动化测试',
    '办公自动化（邮件、表格）',
    '竞品网站监控',
]

for i, s in enumerate(scenarios, 1):
    print(f'{i}. {s}')

# %% [markdown]
# ## 总结
#
# - Computer Use 让 AI 像人一样操控电脑
# - 截屏 → 分析 → 操作 → 循环
# - 需要在沙箱环境中使用
# - 适合自动化测试、数据采集等场景
#
# 第 9 章完成！下一章学习多 Agent 协作。
